# %%
from pandas import *
from pylab import *

# %%
Datos_exp=read_csv('F0001CH2.csv')
#print(Datos_exp.to_string())
Datos_value = read_csv ('F0001CH2.csv', usecols = ['Value'])

# %%
figure(dpi=100)
n=np.linspace(0,11,11)
title("Pulsos prueba")
plot(Datos_value)
xlabel('dx')
grid(True)
show()
